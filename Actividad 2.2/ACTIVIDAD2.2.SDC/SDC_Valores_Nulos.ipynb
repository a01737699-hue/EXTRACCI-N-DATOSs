# %% [markdown]
# # Actividad 2.2 (Valores Nulos)
# Archivo: SDC.xlsx

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **VALORES NULOS**

# %%
#Carga desde un archivo .xlsx sin indice
data = pd.read_excel('SDC.xlsx', header=None)
data.head(5)

# %%
#Eliminar columnas innecesarias
#axis = 1 para columnas
#axis = 0 para filas
data2= data.drop([36], axis=1)
data2

# %%
#Identificar valores nulos por columna
valores_nulos=data2.isnull().sum()
valores_nulos

# %%
#Identificar valores nulos por dataframe
valores_nulos=data2.isnull().sum().sum()
valores_nulos

# %% [markdown]
# **Métodos de Sustitución de Valores Nulos**

# %%
#Realizamos una copia del dataframe
data3=data2.copy()

# %%
#Primer método de sustitución de valores nulos
#Sustituir valores nulos por valores no nulos hacia adelante "forward fill" ("ffill")
#Filtro por columnas
data3[0] =data3[0].ffill()

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Segundo método de sustitución de valores nulos
#Sustituir valores nulos por un valor numérico en concreto
data3[1]= data3[1].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[2]= data3[2].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[3]= data3[3].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[4]= data3[4].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[5]= data3[5].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[6]= data3[6].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[7]= data3[7].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[8]= data3[8].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[9]= data3[9].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[10]= data3[10].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[11]= data3[11].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[12]= data3[12].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[13]= data3[13].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[14]= data3[14].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[15]= data3[15].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[16]= data3[16].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[17]= data3[17].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[18]= data3[18].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[19]= data3[19].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[20]= data3[20].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[21]= data3[21].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[22]= data3[22].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[23]= data3[23].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[24]= data3[24].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[25]= data3[25].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[26]= data3[26].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[27]= data3[27].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[28]= data3[28].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[29]= data3[29].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[30]= data3[30].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[31]= data3[31].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[32]= data3[32].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[33]= data3[33].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[34]= data3[34].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Sustituir valores nulos por un valor numérico en concreto
data3[35]= data3[35].fillna(0)

# %%
#Corroboramos valores nulos
valores_nulos=data3.isnull().sum()
valores_nulos

# %%
#Corroboramos valores nulos en todo el dataframe
valores_nulos=data3.isnull().sum().sum()
valores_nulos

# %% [markdown]
# **Método de Eliminación de valores nulos**

# %%
#Identificar valores nulos por columna
valores_nulos=data2.isnull().sum()
valores_nulos

# %%
#Realizamos una copia del dataframe
data4=data2.copy()
data4

# %%
#Eliminamos filas con nulos
#No se agrega nada para eliminar filas y 1 para eliminar columnas
data4= data2.dropna()
data4

# %%
#Identificar valores nulos por columna
valores_nulos=data4.isnull().sum()
valores_nulos

# %% [markdown]
# **Comparamos DataFrame3(Sustitución) y Dataframe4(Eliminación)**

# %%
data3.info()

# %%
data4.info()

# %% [markdown]
# **Convertir DataSet sin valores nulos a CSV**

# %%
#Convertir DataFrame a CSV
data3.to_csv("SDC_Sin_Nulos.csv", index=False)

# %% [markdown]
# **Técnicas de tratamiento de valores nulos por columna**
#
# | Columna | Técnica |
# |---|---|
# | Columna 36 | Eliminación de columna (96% vacía) |
# | Columna 0 (etiquetas de fila: Generadas/Aprobadas/financieras/motivos) | Sustitución por forward fill (ffill) |
# | Columnas 1 a 35 (meses y resumen, excepto 36) | Sustitución por valor numérico fijo (0): una celda vacía en un reporte mensual significa que no hubo actividad registrada ese mes |
